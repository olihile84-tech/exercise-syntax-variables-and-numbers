# %% [markdown]
# <a href="https://colab.research.google.com/github/olihile84-tech/exercise-syntax-variables-and-numbers/blob/main/Booleans_and_conditionals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install git+https://github.com/Kaggle/learntools.git
# Out:
# ...
#   Cloning https://github.com/Kaggle/learntools.git to /tmp/pip-req-build-c29654za
#   Running command git clone --filter=blob:none --quiet https://github.com/Kaggle/learntools.git /tmp/pip-req-build-c29654za
#   Resolved https://github.com/Kaggle/learntools.git to commit a0c08ac1fa73dd42ba4aecf2cce045752f14f72b
#   Preparing metadata (setup.py) ... done

# %%
from learntools.core import binder; binder.bind(globals())
from learntools.python.ex3 import *
print('Setup complete.')
# Out:
# Setup complete.

# %%
def sign(x):
 if x < 0:
  return -1
 elif x > 0:
    return 1
 else:
      return 0

 q1.check()

# %%
def to_smash(total_candies):
  """Return the number of leftover candies that must be smashed after distributing
    the given number of candies evenly between 3 friends.

    >>> to_smash(91)
    1
    """
  print("Splitting",total_candies, "candies")
  return total_candies % 3
to_smash(91)
# Out:
# Splitting 91 candies
# 1

# %%
def to_smash(total_candies):
    """Return the number of leftover candies that must be smashed after distributing
    the given number of candies evenly between 3 friends.

    >>> to_smash(91)
    1
    """
    if total_candies==1:
      print("Splitting", total_candies, "candy")
    else:
       print("Splitting", total_candies, "candies")
    return total_candies % 3

to_smash(91)
to_smash(1)
# Out:
# Splitting 91 candies
# Splitting 1 candy
# 1

# %%
def prepared_for_weather(have_umbrella,rain_level, have_hood, is_workday):
  return have_umbrella or ((rain_level < 5) and have_hood) or not (rain_level > 0 and is_workday)

  have_umbrella = False
  rain_level = 0.0
  have_hood = False
  is_workday = False

  actual = prepared_for_weather(
      have_umbrella
      or ((rain_level<5)
      and have_hood)
      or (not (rain_level>0 and is_workday))
  )

  q3.check()

# %%
def is_negative(number):
  if number < 0:
    return True
  else:
      return False

def concise_is_negative(x):
    if x < 0:
       return True
    else:
      return False

q4.check()
# Out:
# Correct

# %%
def onionless(ketchup, mustard, onion):
   """Return whether the customer doesn't want onion.
   """
   return not onion

# %%
def wants_all_toppings(ketchup, mustard, onion):
  """Return whether the customer wants "the works" (all 3 toppings)
  """
  return(ketchup and mustard and onion)

q5.a.check()
# Out:
# Correct

# %%
def wants_plain_hotdog(ketchup, mustard, onion):
   """Return whether the customer wants a plain hot dog with no toppings
   """
   return not ketchup and not mustard and not onion

   q5.b.check()

# %%
def exactly_one_sauce(ketchup, mustard, onion):
  """Return whether the customer wants either ketchup or mustard, but not both.
  """
  return (ketchup or mustard) and not (ketchup and mustard)

  q5.c.check()

# %%
def exactly_one_topping(ketchup, mustard, onion):
  """Return whether the customer wants exactly one of the three available toppings
  on their hot dog.
  """
  return(ketchup+mustard+onion)==1

q6.check()
# Out:
# Correct:
#
# This condition would be pretty complicated to express using just `and`, `or` and `not`, but using boolean-to-integer conversion gives us this short solution:
# ```python
# return (int(ketchup) + int(mustard) + int(onion)) == 1
# ```
#
# Fun fact: we don't technically need to call `int` on the arguments. Just by doing addition with booleans, Python implicitly does the integer conversion. So we could also write...
#
# ```python
# return (ketchup + mustard + onion) == 1
# ```

# %%
def should_hit(dealer_total, player_total, player_low_aces, player_high_aces):
  """Return True if the player should hit (request another card) given the current game
  state, or False if the player should stay.
  When calculating a hand's toatal value, we count aces as "high" (with the value 11) if doing so
  doesn't bring the total above 21, otherwise we count them as low (with value 1).
  For example, if the player's hand is (A,A,A,7), we will count it as 11+1+1+7,
  and therefore set player_total+20, player_low_aces=2, player_high_aces=1
  """
  return player_total > 17

q7.simulate(n_games=50000)
# Out:
# Player won 10787 out of 50000 games (win rate = 21.6%)
