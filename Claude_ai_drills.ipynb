# %% [markdown]
# <a href="https://colab.research.google.com/github/olihile84-tech/exercise-syntax-variables-and-numbers/blob/main/Claude_ai_drills.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

np.random.seed(20)

pnl = np.random.randint(-50, 50, size=40)

winners = pnl[(pnl>0)&(pnl>20)]

equity_curve = 5000 + np.cumsum(pnl)

running_peak = np.maximum.accumulate(equity_curve)

pnl_matrix = pnl.reshape(8, 5)
column_means = pnl_matrix.mean(axis=0)
