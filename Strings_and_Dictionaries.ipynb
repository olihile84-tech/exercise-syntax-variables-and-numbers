# %% [markdown]
# <a href="https://colab.research.google.com/github/olihile84-tech/exercise-syntax-variables-and-numbers/blob/main/Strings_and_Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/Kaggle/learntools.git
# Out:
# ...
#   Cloning https://github.com/Kaggle/learntools.git to /tmp/pip-req-build-_9ob396q
#   Running command git clone --filter=blob:none --quiet https://github.com/Kaggle/learntools.git /tmp/pip-req-build-_9ob396q
#   Resolved https://github.com/Kaggle/learntools.git to commit a0c08ac1fa73dd42ba4aecf2cce045752f14f72b
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for learntools: filename=learntools-0.3.5-py3-none-any.whl size=269685 sha256=cd494e2894ee17dce9f47b3adb517474deaa352d6fd4a5c704164c3730bb8a44
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ghhgr_tj/wheels/3e/56/95/47a8734b7e520ce6a601b2d09b8e0714eac8b3d59669123c80
# Successfully built learntools
# ...

# %%
from learntools.core import binder; binder.bind(globals())
from learntools.python.ex6 import *
print('Setup complete')
# Out:
# Setup complete

# %%
a = ""
length = 0
q0.a.check()
# Out:
# Correct:
#
# The empty string has length zero. Note that the empty string is also the only string that Python considers as False when converting to boolean.

# %%
b ="it's ok"
length = 7
q0.b.check()
# Out:
# Correct:
#
# Keep in mind Python includes spaces (and punctuation) when counting string length.

# %%
c = "it\'s ok"
length = 7
q0.c.check()
# Out:
# Correct:
#
# Even though we use different syntax to create it, the string `c` is identical to `b`. In particular, note that the backslash is not part of the string, so it doesn't contribute to its length.

# %%
def is_valid_zip(zip_code):
  return len(zip_code)==5 and zip_code.isdigit()

q1.check()
# Out:
# Correct

# %%
def word_search(doc_list, keyword):
  result = []
  for i in range(len(doc_list)):
        words = doc_list[i].lower().replace(',', '').replace('.', '').split()
        if keyword.lower() in words:
            result.append(i)
  return result

q2.check()
# Out:
# Correct

# %%
def multi_word_search(doc_list, keyword):
  result = []
  result = []
  for keyword in keywords:
    result[keyword] = word_search(doc_list, keyword)
    return result

q3.check()
# Out:
# Incorrect: When calling your function with arguments `[['The Learn Python Challenge Casino', 'They bought a car', 'Casinoville?'], []]`, Python raised the following exception... **`NameError: name 'keywords' is not defined`**

# %%
help(dict)
# Out:
# Help on class dict in module builtins:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Built-in subclasses:
#  |      StgDict
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if the dictionary has the specified key, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
# ...
